# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
n = int(input().strip())
if n%2 != 0:
    print("Weird")
elif n in range(2,6):
    print("Not Weird")
elif n in range(6,21):
    print("Weird")
elif n > 20:
    print("Not Weird")
# Out:
# Weird

# %%
a = int(input())
b = int(input())
print(a+b)
print(a-b)
print(a*b)
# Out:
# 15
# -5
# 50

# %%
a = int(input())
b = int(input())
print(a//b)
print(a/b)
# Out:
# 0
# 0.8333333333333334

# %%
n = 4
for i in range(n):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9

# %%
def is_leap(year):
    leap = False
    if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
        return True
    else:
        return False

print(is_leap(1992))
# Out:
# True

# %%
n = int(input())
string = ""
for i in range(1,n+1):
    string+=str(i)
print(string)
# Out:
# 1234
